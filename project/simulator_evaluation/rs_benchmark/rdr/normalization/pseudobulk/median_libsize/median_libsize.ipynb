# %%
# %load_ext autoreload
# %autoreload 2

# %%
import anndata as ad
import logging
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scanpy as sc
import seaborn as sns
import sys
from matplotlib.lines import Line2D
from sccnasim.utils.gcna import load_cnas

# %%
utils_dir = "/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/rs_benchmark/rdr/base/scripts"
sys.path.append(utils_dir)
from ubase import *
from urdr import *

# %%
cna_fn = '/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/base/data/cna_profile.tsv'
in_dir = '/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/rs_benchmark/rdr/base/pp'
out_dir = '/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/rs_benchmark/rdr/normalization/pseudobulk/median_libsize'
chrom_anno_fn = '/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/rs_benchmark/rdr/normalization/pseudobulk/data/chrom_arm_length.3col.tsv'

# %%
min_cells_per_gene = 3
min_gene_mean = 0.1

# %%
blue = '#0072B2'
orange = '#E69F00'
green = '#009E73'
red = '#D55E00'     # Vermillion

def_color = blue

# %%
cw_prefix = 'cw-'
gw_prefix = 'gw-'

dpi = 300

# %%
tool_labels = ['seed_N', 'stCNASim-rs_N', 'scReadSim-cna_N', 'stCNASim-rs_T', 'scReadSim-cna_T']

# %% [markdown]
# # Prepare Data

# %% [markdown]
# ## Generate annotation of gene CNA type

# %%
os.makedirs(out_dir, exist_ok = True)

# %%
cna = load_cnas(cna_fn)
cna
# Out:
#   chrom      start        end  clone  cn_ale0  cn_ale1                 region
# 0     1  123400001  248956422  tumor        1        2  1:123400001-248956422
# 1     4   50000001  190214555  tumor        0        1   4:50000001-190214555
# 2     8          1   45200000  tumor        0        1           8:1-45200000
# 3     8   45200001  145138636  tumor        1        2   8:45200001-145138636
# 4    13   17700001  114364328  tumor        2        0  13:17700001-114364328
# 5    17          1   25100000  tumor        2        0          17:1-25100000

# %%
adata = ad.read_h5ad(os.path.join(in_dir, "rs_normal.h5ad"))
adata
# Out:
# AnnData object with n_obs × n_vars = 600 × 32272
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'

# %%
gene_anno = adata.var.copy()
gene_anno['gene'] = gene_anno['feature']
gene_anno['gene_cna_type'] = 'N.A.'
gene_anno
# Out:
#                      gene_id         gene chrom       start         end  \
# MIR1302-2HG  ENSG00000243485  MIR1302-2HG     1     29554.0     31109.0
# FAM138A      ENSG00000237613      FAM138A     1     34554.0     36081.0
# OR4F5        ENSG00000186092        OR4F5     1     65419.0     71585.0
# AL627309.1   ENSG00000238009   AL627309.1     1     89295.0    133723.0
# AL627309.3   ENSG00000239945   AL627309.3     1     89551.0     91105.0
# ...                      ...          ...   ...         ...         ...
# C21orf58     ENSG00000160298     C21orf58    21  46300181.0  46323875.0
# PCNT         ENSG00000160299         PCNT    21  46324122.0  46445769.0
# DIP2A        ENSG00000160305        DIP2A    21  46458899.0  46569852.0
# S100B        ENSG00000160307        S100B    21  46598962.0  46605208.0
# PRMT2        ENSG00000160310        PRMT2    21  46635167.0  46665124.0
#
#             strand      feature gene_cna_type
# MIR1302-2HG      +  MIR1302-2HG          N.A.
# FAM138A          -      FAM138A          N.A.
# OR4F5            +        OR4F5          N.A.
# AL627309.1       -   AL627309.1          N.A.
# AL627309.3       -   AL627309.3          N.A.
# ...            ...          ...           ...
# C21orf58         -     C21orf58          N.A.
# PCNT             +         PCNT          N.A.
# DIP2A            +        DIP2A          N.A.
# S100B            -        S100B          N.A.
# PRMT2            +        PRMT2          N.A.
#
# [32272 rows x 8 columns]

# %%
def is_cna_feature(x, df):
    chrom, start, end = x["chrom"], x["start"], x["end"]
    d = df[(df["chrom"] == chrom) & (df["start"] <= end) & (df["end"] >= start)]
    return(d.shape[0] > 0)

# %%
# Neutral genes
bool_is_cna = adata.var.apply(is_cna_feature, axis = 1, df = cna)
cna_genes = adata.var["feature"][bool_is_cna].to_numpy()
print(cna_genes.shape)

gene_anno.loc[~(gene_anno['gene'].isin(cna_genes)), 'gene_cna_type'] = 'Neutral'
gene_anno['gene_cna_type'].value_counts()
# Out:
# (4968,)
# gene_cna_type
# Neutral    27304
# N.A.        4968
# Name: count, dtype: int64

# %%
# Gain genes
df_cna = cna.loc[cna['cn_ale0'] + cna['cn_ale1'] > 2].copy()
bool_is_cna = adata.var.apply(is_cna_feature, axis = 1, df = df_cna)
cna_genes = adata.var["feature"][bool_is_cna].to_numpy()
print(cna_genes.shape)

assert np.all(gene_anno.loc[gene_anno['gene'].isin(cna_genes), 'gene_cna_type'] == 'N.A.')
gene_anno.loc[gene_anno['gene'].isin(cna_genes), 'gene_cna_type'] = 'Gain'
gene_anno['gene_cna_type'].value_counts()
# Out:
# (2301,)
# gene_cna_type
# Neutral    27304
# N.A.        2667
# Gain        2301
# Name: count, dtype: int64

# %%
# Loss genes
df_cna = cna.loc[cna['cn_ale0'] + cna['cn_ale1'] < 2].copy()
bool_is_cna = adata.var.apply(is_cna_feature, axis = 1, df = df_cna)
cna_genes = adata.var["feature"][bool_is_cna].to_numpy()
print(cna_genes.shape)

assert np.all(gene_anno.loc[gene_anno['gene'].isin(cna_genes), 'gene_cna_type'] == 'N.A.')
gene_anno.loc[gene_anno['gene'].isin(cna_genes), 'gene_cna_type'] = 'Loss'
gene_anno['gene_cna_type'].value_counts()
# Out:
# (1437,)
# gene_cna_type
# Neutral    27304
# Gain        2301
# Loss        1437
# N.A.        1230
# Name: count, dtype: int64

# %%
# LOH genes
df_cna = cna.loc[cna['cn_ale0'] + cna['cn_ale1'] == 2].copy()
bool_is_cna = adata.var.apply(is_cna_feature, axis = 1, df = df_cna)
cna_genes = adata.var["feature"][bool_is_cna].to_numpy()
print(cna_genes.shape)

assert np.all(gene_anno.loc[gene_anno['gene'].isin(cna_genes), 'gene_cna_type'] == 'N.A.')
gene_anno.loc[gene_anno['gene'].isin(cna_genes), 'gene_cna_type'] = 'LOH'
gene_anno['gene_cna_type'].value_counts()
# Out:
# (1230,)
# gene_cna_type
# Neutral    27304
# Gain        2301
# Loss        1437
# LOH         1230
# Name: count, dtype: int64

# %% [markdown]
# ## Load adata files

# %%
seed_normal_fn = os.path.join(in_dir, "seed_normal.h5ad")
rs_normal_fn = os.path.join(in_dir, "rs_normal.h5ad")
rs_tumor_fn = os.path.join(in_dir, "rs_tumor.h5ad")
scrs_normal_fn = os.path.join(in_dir, "scrs_normal.h5ad")
scrs_tumor_fn = os.path.join(in_dir, "scrs_tumor.h5ad")

# %%
seed_normal = ad.read_h5ad(seed_normal_fn)
print(seed_normal)

rs_normal = ad.read_h5ad(rs_normal_fn)
print(rs_normal)

rs_tumor = ad.read_h5ad(rs_tumor_fn)
print(rs_tumor)

scrs_normal = ad.read_h5ad(scrs_normal_fn)
print(scrs_normal)

scrs_tumor = ad.read_h5ad(scrs_tumor_fn)
print(scrs_tumor)
# Out:
# AnnData object with n_obs × n_vars = 600 × 32272
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 32272
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 32272
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 32272
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 32272
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'

# %% [markdown]
# ## Load chrom annotations

# %%
chrom_anno = pd.read_csv(chrom_anno_fn, sep = '\t')
chrom_anno
# Out:
#     chrom  q_arm_start  q_arm_end
# 0       1    123400000  248956422
# 1       2     93900000  242193529
# 2       3     90900000  198295559
# 3       4     50000000  190214555
# 4       5     48800000  181538259
# 5       6     59800000  170805979
# 6       7     60100000  159345973
# 7       8     45200000  145138636
# 8       9     43000000  138394717
# 9      10     39800000  133797422
# 10     11     53400000  135086622
# 11     12     35500000  133275309
# 12     13     17700000  114364328
# 13     14     17200000  107043718
# 14     15     19000000  101991189
# 15     16     36800000   90338345
# 16     17     25100000   83257441
# 17     18     18500000   80373285
# 18     19     26200000   58617616
# 19     20     28100000   64444167
# 20     21     12000000   46709983
# 21     22     15000000   50818468

# %% [markdown]
# # Get metrics

# %%
mv = get_gw_metrics_group(
    X_lst = [seed_normal.X, rs_normal.X, scrs_normal.X, rs_tumor.X, scrs_tumor.X],
    X_names = tool_labels,
    id_lst = [seed_normal.var['feature'].to_numpy(), rs_normal.var['feature'].to_numpy(), scrs_normal.var['feature'].to_numpy(),
             rs_tumor.var['feature'].to_numpy(), scrs_tumor.var['feature'].to_numpy()],
    metrics = ["mean", "var", "cv", "zero_prop"]
)
mv = mv.rename(columns = dict(X_name = 'group'))
mv
# Out:
#             mean       var         cv  zero_prop            group      feature
# 0       0.000000  0.000000   0.000000   1.000000           seed_N  MIR1302-2HG
# 1       0.000000  0.000000   0.000000   1.000000           seed_N      FAM138A
# 2       0.000000  0.000000   0.000000   1.000000           seed_N        OR4F5
# 3       0.003333  0.003322  17.291616   0.996667           seed_N   AL627309.1
# 4       0.000000  0.000000   0.000000   1.000000           seed_N   AL627309.3
# ...          ...       ...        ...        ...              ...          ...
# 161355  0.001667  0.001664  24.474475   0.998333  scReadSim-cna_T     C21orf58
# 161356  0.101667  0.101331   3.131062   0.903333  scReadSim-cna_T         PCNT
# 161357  0.100000  0.103333   3.214550   0.906667  scReadSim-cna_T        DIP2A
# 161358  0.013333  0.013156   8.602325   0.986667  scReadSim-cna_T        S100B
# 161359  0.265000  0.278108   1.990037   0.773333  scReadSim-cna_T        PRMT2
#
# [161360 rows x 6 columns]

# %%
tmp = mv[["group", "feature", "mean", "var", "cv", "zero_prop"]]

tmp.to_csv(
    os.path.join(out_dir, gw_prefix + "metric_values_raw.tsv"), 
    header = True, 
    index = False, 
    sep = "\t"
)

# %% [markdown]
# # Filter genes

# %%
mv_seed = mv.loc[mv['group'] == 'seed_N'].copy()
mv_seed['gene'] = mv_seed['feature']
mv_seed
# Out:
#            mean       var         cv  zero_prop   group      feature  \
# 0      0.000000  0.000000   0.000000   1.000000  seed_N  MIR1302-2HG
# 1      0.000000  0.000000   0.000000   1.000000  seed_N      FAM138A
# 2      0.000000  0.000000   0.000000   1.000000  seed_N        OR4F5
# 3      0.003333  0.003322  17.291616   0.996667  seed_N   AL627309.1
# 4      0.000000  0.000000   0.000000   1.000000  seed_N   AL627309.3
# ...         ...       ...        ...        ...     ...          ...
# 32267  0.003333  0.003322  17.291616   0.996667  seed_N     C21orf58
# 32268  0.135000  0.143442   2.805459   0.878333  seed_N         PCNT
# 32269  0.095000  0.092642   3.203905   0.908333  seed_N        DIP2A
# 32270  0.006667  0.006622  12.206555   0.993333  seed_N        S100B
# 32271  0.260000  0.292400   2.079770   0.785000  seed_N        PRMT2
#
#               gene
# 0      MIR1302-2HG
# 1          FAM138A
# 2            OR4F5
# 3       AL627309.1
# 4       AL627309.3
# ...            ...
# 32267     C21orf58
# 32268         PCNT
# 32269        DIP2A
# 32270        S100B
# 32271        PRMT2
#
# [32272 rows x 7 columns]

# %%
n_cell = seed_normal.shape[0]
cutoff = 1 - min_cells_per_gene / n_cell
print(cutoff)
flag = mv_seed['zero_prop'] >= cutoff
n_gene = np.sum(flag)
print("%d genes will be excluded (min_cells_per_gene = %d)" % (n_gene, min_cells_per_gene))
# Out:
# 0.995
# 18128 genes will be excluded (min_cells_per_gene = 3)

# %%
flag = mv_seed['mean'] < min_gene_mean
n_gene = np.sum(flag)
print("%d genes will be excluded (min_gene_mean = %f)" % (n_gene, min_gene_mean))
# Out:
# 24407 genes will be excluded (min_gene_mean = 0.100000)

# %%
flag = mv_seed['zero_prop'] >= 1 - min_cells_per_gene / n_cell
flag |= mv_seed['mean'] < min_gene_mean
n_gene = np.sum(flag)
print("%d genes will be excluded (min_cells_per_gene = %d; min_gene_mean = %f)" % (n_gene, min_cells_per_gene, min_gene_mean))
# Out:
# 24407 genes will be excluded (min_cells_per_gene = 3; min_gene_mean = 0.100000)

# %%
flag = mv_seed['zero_prop'] >= 1 - min_cells_per_gene / n_cell
flag |= mv_seed['mean'] < min_gene_mean
valid_genes = mv_seed.loc[~flag, 'feature'].to_numpy()
valid_genes.shape
# Out:
# (7865,)

# %% [markdown]
# # Subset adata and normalize total counts

# %%
seed_normal = seed_normal[:, seed_normal.var['feature'].isin(valid_genes)].copy()
print(seed_normal)

rs_normal = rs_normal[:, rs_normal.var['feature'].isin(valid_genes)].copy()
print(rs_normal)

scrs_normal = scrs_normal[:, scrs_normal.var['feature'].isin(valid_genes)].copy()
print(scrs_normal)

rs_tumor = rs_tumor[:, rs_tumor.var['feature'].isin(valid_genes)].copy()
print(rs_tumor)

scrs_tumor = scrs_tumor[:, scrs_tumor.var['feature'].isin(valid_genes)].copy()
print(scrs_tumor)
# Out:
# AnnData object with n_obs × n_vars = 600 × 7865
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 7865
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 7865
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 7865
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'
# AnnData object with n_obs × n_vars = 600 × 7865
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'feature'

# %%
total_counts = np.array([])
for adata in [seed_normal, rs_normal, scrs_normal, rs_tumor, scrs_tumor]:
    counts = adata.X.sum(axis = 1)
    counts = np.array(counts).reshape(-1)
    total_counts = np.concatenate((total_counts, counts))
median_total_counts = np.ceil(np.median(total_counts))
median_total_counts
# Out:
# 8977.0

# %%
# seed data
total_counts = np.array([])
for adata in [seed_normal]:
    counts = adata.X.sum(axis = 1)
    counts = np.array(counts).reshape(-1)
    total_counts = np.concatenate((total_counts, counts))
median_total_counts = np.ceil(np.median(total_counts))
print(median_total_counts)

seed_normal.X = seed_normal.X.astype('float32')
sc.pp.normalize_total(seed_normal, target_sum = median_total_counts)
# Out:
# 9635.0

# %%
# two cs count matrices
total_counts = np.array([])
for adata in [rs_normal, rs_tumor]:
    counts = adata.X.sum(axis = 1)
    counts = np.array(counts).reshape(-1)
    total_counts = np.concatenate((total_counts, counts))
median_total_counts = np.ceil(np.median(total_counts))
print(median_total_counts)

rs_normal.X = rs_normal.X.astype('float32')
sc.pp.normalize_total(rs_normal, target_sum = median_total_counts)

rs_tumor.X = rs_tumor.X.astype('float32')
sc.pp.normalize_total(rs_tumor, target_sum = median_total_counts)
# Out:
# 8626.0

# %%
# two scDesign2-ind count matrices
total_counts = np.array([])
for adata in [scrs_normal, scrs_tumor]:
    counts = adata.X.sum(axis = 1)
    counts = np.array(counts).reshape(-1)
    total_counts = np.concatenate((total_counts, counts))
median_total_counts = np.ceil(np.median(total_counts))
print(median_total_counts)

scrs_normal.X = scrs_normal.X.astype('float32')
sc.pp.normalize_total(scrs_normal, target_sum = median_total_counts)

scrs_tumor.X = scrs_tumor.X.astype('float32')
sc.pp.normalize_total(scrs_tumor, target_sum = median_total_counts)
# Out:
# 9049.0

# %% [markdown]
# # Re-calculate metrics

# %%
mv = get_gw_metrics_group(
    X_lst = [seed_normal.X, rs_normal.X, scrs_normal.X, rs_tumor.X, scrs_tumor.X],
    X_names = tool_labels,
    id_lst = [seed_normal.var['feature'].to_numpy(), rs_normal.var['feature'].to_numpy(), scrs_normal.var['feature'].to_numpy(),
             rs_tumor.var['feature'].to_numpy(), scrs_tumor.var['feature'].to_numpy()],
    metrics = ["mean", "var", "cv", "zero_prop"]
)
mv = mv.rename(columns = dict(X_name = 'group'))
mv
# Out:
#            mean       var        cv  zero_prop            group   feature
# 0      0.252513  0.291711  2.138915   0.776667           seed_N     NOC2L
# 1      0.122353  0.139225  3.049607   0.883333           seed_N      HES4
# 2      0.469264  0.572922  1.612985   0.625000           seed_N     ISG15
# 3      0.376642  0.378917  1.634344   0.663333           seed_N      AGRN
# 4      0.092866  0.091569  3.258475   0.898333           seed_N  C1orf159
# ...         ...       ...       ...        ...              ...       ...
# 39320  0.646293  0.711817  1.305433   0.518333  scReadSim-cna_T       LSS
# 39321  0.246498  0.264421  2.086096   0.775000  scReadSim-cna_T    MCM3AP
# 39322  0.088387  0.115946  3.852474   0.921667  scReadSim-cna_T      YBEY
# 39323  0.100611  0.111994  3.326233   0.903333  scReadSim-cna_T      PCNT
# 39324  0.258927  0.331457  2.223495   0.773333  scReadSim-cna_T     PRMT2
#
# [39325 rows x 6 columns]

# %%
tmp = mv[["group", "feature", "mean", "var", "cv", "zero_prop"]]

tmp.to_csv(
    os.path.join(out_dir, gw_prefix + "metric_values.tsv"), 
    header = True, 
    index = False, 
    sep = "\t"
)

# %% [markdown]
# # Calculate log2FC

# %%
pairs = [
    ("stCNASim-rs_T", "stCNASim-rs_N"),
    ("scReadSim-cna_T", "scReadSim-cna_N")
]

selected_gvars = pd.DataFrame(data = dict(
    x = [p[1] for p in pairs],
    y = [p[0] for p in pairs],
))

# %%
st_log2fc = stat_log2fc(
    data = mv,
    metric = "mean", group = "group", gvars = selected_gvars
)
genes = mv.loc[mv['group'] == 'seed_N', 'feature'].to_numpy()
st_log2fc['gene'] = np.tile(genes, int(st_log2fc.shape[0] / len(genes)))
print(st_log2fc)


tmp = st_log2fc.copy()
tmp.to_csv(
    os.path.join(out_dir, gw_prefix + "log2fc-vs-mean.tsv"), 
    header = True, 
    index = False, 
    sep = "\t"
)
# Out:
#                      x                y    mean_x    mean_y    log2FC  \
# 0        stCNASim-rs_N    stCNASim-rs_T  0.202232  0.209727  0.052500
# 1        stCNASim-rs_N    stCNASim-rs_T  0.093370  0.099944  0.098163
# 2        stCNASim-rs_N    stCNASim-rs_T  0.397898  0.372512 -0.095110
# 3        stCNASim-rs_N    stCNASim-rs_T  0.375811  0.376938  0.004320
# 4        stCNASim-rs_N    stCNASim-rs_T  0.101778  0.082046 -0.310918
# ...                ...              ...       ...       ...       ...
# 15725  scReadSim-cna_N  scReadSim-cna_T  0.619314  0.646293  0.061517
# 15726  scReadSim-cna_N  scReadSim-cna_T  0.244109  0.246498  0.014052
# 15727  scReadSim-cna_N  scReadSim-cna_T  0.065955  0.088387  0.422344
# 15728  scReadSim-cna_N  scReadSim-cna_T  0.129365  0.100611 -0.362660
# 15729  scReadSim-cna_N  scReadSim-cna_T  0.283564  0.258927 -0.131127
#
#            gene
# 0         NOC2L
# 1          HES4
# 2         ISG15
# 3          AGRN
# 4      C1orf159
# ...         ...
# 15725       LSS
# 15726    MCM3AP
# 15727      YBEY
# 15728      PCNT
# 15729     PRMT2
#
# [15730 rows x 6 columns]

# %%
st_log2fc_valid = st_log2fc.loc[st_log2fc['gene'].isin(valid_genes)].copy()
st_log2fc_valid = st_log2fc_valid.merge(gene_anno, on = 'gene', how = 'left')
st_log2fc_valid
# Out:
#                      x                y    mean_x    mean_y    log2FC  \
# 0        stCNASim-rs_N    stCNASim-rs_T  0.202232  0.209727  0.052500
# 1        stCNASim-rs_N    stCNASim-rs_T  0.093370  0.099944  0.098163
# 2        stCNASim-rs_N    stCNASim-rs_T  0.397898  0.372512 -0.095110
# 3        stCNASim-rs_N    stCNASim-rs_T  0.375811  0.376938  0.004320
# 4        stCNASim-rs_N    stCNASim-rs_T  0.101778  0.082046 -0.310918
# ...                ...              ...       ...       ...       ...
# 15725  scReadSim-cna_N  scReadSim-cna_T  0.619314  0.646293  0.061517
# 15726  scReadSim-cna_N  scReadSim-cna_T  0.244109  0.246498  0.014052
# 15727  scReadSim-cna_N  scReadSim-cna_T  0.065955  0.088387  0.422344
# 15728  scReadSim-cna_N  scReadSim-cna_T  0.129365  0.100611 -0.362660
# 15729  scReadSim-cna_N  scReadSim-cna_T  0.283564  0.258927 -0.131127
#
#            gene          gene_id chrom       start         end strand  \
# 0         NOC2L  ENSG00000188976     1    944204.0    959309.0      -
# 1          HES4  ENSG00000188290     1    998962.0   1000172.0      -
# 2         ISG15  ENSG00000187608     1   1001138.0   1014541.0      +
# 3          AGRN  ENSG00000188157     1   1020123.0   1056118.0      +
# 4      C1orf159  ENSG00000131591     1   1081818.0   1116361.0      -
# ...         ...              ...   ...         ...         ...    ...
# 15725       LSS  ENSG00000160285    21  46188141.0  46228824.0      -
# 15726    MCM3AP  ENSG00000160294    21  46235126.0  46286297.0      -
# 15727      YBEY  ENSG00000182362    21  46286337.0  46297751.0      +
# 15728      PCNT  ENSG00000160299    21  46324122.0  46445769.0      +
# 15729     PRMT2  ENSG00000160310    21  46635167.0  46665124.0      +
#
#         feature gene_cna_type
# 0         NOC2L       Neutral
# 1          HES4       Neutral
# 2         ISG15       Neutral
# 3          AGRN       Neutral
# 4      C1orf159       Neutral
# ...         ...           ...
# 15725       LSS       Neutral
# 15726    MCM3AP       Neutral
# 15727      YBEY       Neutral
# 15728      PCNT       Neutral
# 15729     PRMT2       Neutral
#
# [15730 rows x 13 columns]

# %% [markdown]
# # Plot RDR signals

# %%
chr_info = {}
for i in range(chrom_anno.shape[0]):
    chr_info[str(chrom_anno['chrom'].iloc[i])] = (
        chrom_anno['q_arm_end'].iloc[i],
        chrom_anno['q_arm_start'].iloc[i]
    )
chr_info
# Out:
# {'1': (248956422, 123400000),
#  '2': (242193529, 93900000),
#  '3': (198295559, 90900000),
#  '4': (190214555, 50000000),
#  '5': (181538259, 48800000),
#  '6': (170805979, 59800000),
#  '7': (159345973, 60100000),
#  '8': (145138636, 45200000),
#  '9': (138394717, 43000000),
#  '10': (133797422, 39800000),
#  '11': (135086622, 53400000),
#  '12': (133275309, 35500000),
#  '13': (114364328, 17700000),
#  '14': (107043718, 17200000),
#  '15': (101991189, 19000000),
#  '16': (90338345, 36800000),
#  '17': (83257441, 25100000),
#  '18': (80373285, 18500000),
#  '19': (58617616, 26200000),
#  '20': (64444167, 28100000),
#  '21': (46709983, 12000000),
#  '22': (50818468, 15000000)}

# %%
def plot_rdr(st_log2fc, out_fn, figsize = (10, 1), dpi = 300):
    chr_list = list(chr_info.keys())
    x_total = 0
    chr_bounds = {}
    arm_bounds = []
    gap = 1e7      # otherwise, points could overlap bound lines.
    fontsize = 7

    for chr_num in chr_list:
        len_chr, cen_pos = chr_info[chr_num]
        p_start = x_total
        q_start = x_total + cen_pos + gap
        chr_end = x_total + len_chr + gap*2
        chr_bounds[chr_num] = (p_start, q_start, chr_end)
        arm_bounds.append(q_start)
        x_total = chr_end

    color_dict = {
        "Gain": "#D14050",
        "Loss": "#0078BB",
        "LOH": "#40B5A8",
        "Neutral": '#B3B3B3'
    }

    df = pd.DataFrame(data = {
        'chr': st_log2fc['chrom'].astype(str),
        'x': (st_log2fc['start'] + st_log2fc['end']) / 2.0,
        'log2FC': st_log2fc['log2FC'],
        'cnv_state': st_log2fc['gene_cna_type']
    })
    for chr_num in chr_list:
        df.loc[df['chr'] == chr_num, 'x'] += chr_bounds[chr_num][0] + gap

    # Plot
    fig, ax = plt.subplots(1, 1, figsize = figsize, dpi = dpi)

    ax.axhline(0, color = 'black', lw = 1, ls = '--', alpha = 0.7)
    for chr_num in chr_list:    # Chromosome and arm borders
        ax.axvline(chr_bounds[chr_num][0], color = "#bbbbbb", lw = 1.0, zorder = 0)
    for pos in arm_bounds:
        ax.axvline(pos, color = "#e0e0e0", lw = 0.5, ls = '--', zorder = 0)

    # Neutral genes
    pointsize = 2
    neu = df[df.cnv_state == "Neutral"]
    sns.scatterplot(
        data = neu, x = "x", y = "log2FC", 
        color = color_dict["Neutral"], s = pointsize, alpha = 0.9, 
        ax = ax, zorder = 1
    )
    # CNA genes
    for state in ["Gain", "Loss", "LOH"]:
        sub = df[df.cnv_state == state]
        sns.scatterplot(
            data = sub, x = "x", y = "log2FC", color = color_dict[state], 
            s = pointsize, alpha = 0.9, 
            ax = ax, zorder = 2
        )
    # Median line.
    for chr_num in chr_list:
        sub = df.loc[(df.chr == chr_num) & (df.x < chr_bounds[chr_num][1])].sort_values("x")
        ax.hlines(sub.log2FC.median(), xmin = sub.x.min(), xmax = sub.x.max(), color = "#8B0000", lw = 1, zorder = 3)
        sub = df.loc[(df.chr == chr_num) & (df.x >= chr_bounds[chr_num][1])].sort_values("x")
        ax.hlines(sub.log2FC.median(), xmin = sub.x.min(), xmax = sub.x.max(), color = "#8B0000", lw = 1, zorder = 3)

    markersize = fontsize - 1.5
    legend_elements = [
        Line2D([0],[0], marker = 'o', color = 'w', markerfacecolor = color_dict["Gain"], 
               markersize = markersize, label = 'Gain'),
        Line2D([0],[0], marker = 'o', color = 'w', markerfacecolor = color_dict["Loss"], 
               markersize = markersize, label = 'Loss'),
        Line2D([0],[0], marker = 'o', color = 'w', markerfacecolor = color_dict["LOH"], 
               markersize = markersize, label = 'LOH'),
        Line2D([0],[0], marker = 'o', color = 'w', markerfacecolor = color_dict["Neutral"], 
               markersize = markersize, label = 'Neutral')
    ]
    fig.legend(
        handles = legend_elements, loc = "center left", bbox_to_anchor = (0.975, 0.5), 
        frameon = False, fontsize = fontsize, handletextpad = 0.1)

    for ax in [ax]:
        ax.spines['top'].set_visible(True)
        ax.spines['right'].set_visible(True)

    ax.set_xlabel(None)
    ax.set_ylabel(r"Log$_2$FC", fontsize = fontsize)
    ax.set_xticks([(v[0]+v[2])/2 for v in chr_bounds.values()])
    ax.set_xticklabels([str(c) for c in chr_list], fontsize = fontsize)
    ax.tick_params(axis = 'x', length = 0)
    ax.set_xlim(0, chr_bounds['22'][-1])
    ax.set_yticks([-2, -1, 0, 1, 2])
    ax.set_yticklabels(
        ax.get_yticklabels(), 
        fontsize = fontsize - 1
    )

    plt.tight_layout()
    fig.savefig(out_fn, dpi = dpi, bbox_inches = 'tight')

# %%
st_log2fc = st_log2fc_valid.loc[st_log2fc_valid['x'] == 'stCNASim-rs_N'].copy()
print(st_log2fc.shape)
fn = os.path.join(out_dir, gw_prefix + "rdr-stCNASim-rs.png")
plot_rdr(st_log2fc, out_fn = fn, figsize = (7, 1))
# Out:
# (7865, 13)

# %%
st_log2fc = st_log2fc_valid.loc[st_log2fc_valid['x'] == 'scReadSim-cna_N'].copy()
print(st_log2fc.shape)
fn = os.path.join(out_dir, gw_prefix + "rdr-scReadSim-cna.png")
plot_rdr(st_log2fc, out_fn = fn, figsize = (7, 1))
# Out:
# (7865, 13)

# %% [markdown]
# ### Re-centering

# %%
st_log2fc = st_log2fc_valid.loc[st_log2fc_valid['x'] == 'stCNASim-rs_N'].copy()
print(st_log2fc.shape)
baseline = st_log2fc.loc[st_log2fc['gene_cna_type'] == 'Neutral', 'log2FC'].median()
print(baseline)

st_log2fc['log2FC'] -= baseline
fn = os.path.join(out_dir, gw_prefix + "rdr-stCNASim-rs-recentering.png")
plot_rdr(st_log2fc, out_fn = fn, figsize = (7, 1))
# Out:
# (7865, 13)
# 0.09724725

# %%
st_log2fc = st_log2fc_valid.loc[st_log2fc_valid['x'] == 'scReadSim-cna_N'].copy()
print(st_log2fc.shape)
baseline = st_log2fc.loc[st_log2fc['gene_cna_type'] == 'Neutral', 'log2FC'].median()
print(baseline)

st_log2fc['log2FC'] -= baseline
fn = os.path.join(out_dir, gw_prefix + "rdr-scReadSim-cna-recentering.png")
plot_rdr(st_log2fc, out_fn = fn, figsize = (7, 1))
# Out:
# (7865, 13)
# 0.062971696
