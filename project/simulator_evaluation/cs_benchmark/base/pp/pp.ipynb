# %%
# pp.ipynb - preprocess count data and save into formatted adata files.

# %%
import anndata as ad
import numpy as np
import os
import pandas as pd
import scanpy as sc

# %%
seed_fn = "/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/base/gen_data/sccnasim/simu/2_afc/afc.counts.cell_anno.h5ad"
cs_fn = "/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/base/gen_data/sccnasim/simu/3_cs/cs.counts.h5ad"
ind_fn = "/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/base/gen_data/afc_scdesign2_ind/cna_matrix/scDesign2_ind.cna_matrix.h5ad"

out_dir = "/groups/cgsd/xianjie/projects/cna-benchmark/HCC3N_600spot/simulator_evaluation/cs_benchmark/base/pp"

# %%
normal_cell_type = "normal"
tumor_cell_type = "tumor"

# %% [markdown]
# # Load Data

# %%
os.makedirs(out_dir, exist_ok = True)

# %% [markdown]
# ### Seed data (scCNASim afc)

# %%
seed = ad.read_h5ad(seed_fn)
seed
# Out:
# /home/xianjie/.anaconda3/envs/SCSC/lib/python3.11/site-packages/anndata-0.10.7-py3.11.egg/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 600 × 32295
#     obs: 'cell', 'cell_type'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'

# %%
seed = seed[:, ~seed.var["feature"].duplicated(keep = False)].copy()
seed.X = seed.layers["A"] + seed.layers["B"] + seed.layers["U"]
seed.obs.index = seed.obs["cell"]
seed.var.index = seed.var["feature"]
seed
# Out:
# AnnData object with n_obs × n_vars = 600 × 32295
#     obs: 'cell', 'cell_type'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'

# %%
seed.X.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### scCNASim cs

# %%
cs = ad.read_h5ad(cs_fn)
cs
# Out:
# AnnData object with n_obs × n_vars = 1200 × 32295
#     obs: 'cell_type', 'cell'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'

# %%
cs = cs[:, ~cs.var["feature"].duplicated(keep = False)].copy()
cs.X = cs.layers["A"] + cs.layers["B"] + cs.layers["U"]
cs.obs.index = cs.obs["cell"]
cs.var.index = cs.var["feature"]
cs
# Out:
# AnnData object with n_obs × n_vars = 1200 × 32295
#     obs: 'cell_type', 'cell'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'

# %%
cs.X.dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### scDesign2 independent (ind) mode

# %%
ind = ad.read_h5ad(ind_fn)
ind
# Out:
# /home/xianjie/.anaconda3/envs/SCSC/lib/python3.11/site-packages/anndata-0.10.7-py3.11.egg/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 1200 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'region', 'cn0', 'cn1', 'cna_type'

# %%
ind.var['feature'] = ind.var['gene']
ind = ind[:, ~ind.var["feature"].duplicated(keep = False)].copy()
ind.obs.index = ind.obs["cell"]
ind.var.index = ind.var["feature"]
ind
# Out:
# AnnData object with n_obs × n_vars = 1200 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'region', 'cn0', 'cn1', 'cna_type', 'feature'

# %%
ind.X.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## Use intersect genes

# %%
adata_list = [seed, cs, ind]

genes = None
for i, adata in enumerate(adata_list):
    if i == 0:
        genes = adata.var["feature"].to_numpy()
    else:
        genes = np.intersect1d(genes, adata.var["feature"])
genes.shape
# Out:
# (32286,)

# %% [markdown]
# ### Use the same order of genes

# %%
seed = seed[:, seed.var["feature"].isin(genes)].copy()
print(seed)

cs = cs[:, seed.var.index].copy()
print(cs)

ind = ind[:, seed.var.index].copy()
print(ind)
# Out:
# AnnData object with n_obs × n_vars = 600 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'
# AnnData object with n_obs × n_vars = 1200 × 32286
#     obs: 'cell_type', 'cell'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'
# AnnData object with n_obs × n_vars = 1200 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'region', 'cn0', 'cn1', 'cna_type', 'feature'

# %% [markdown]
# ## Split by cell type

# %%
seed_normal = seed[seed.obs["cell_type"] == normal_cell_type, :].copy()
print(seed_normal)

cs_normal = cs[cs.obs["cell_type"] == normal_cell_type, :].copy()
print(cs_normal)

cs_tumor = cs[cs.obs["cell_type"] == tumor_cell_type, :].copy()
print(cs_tumor)

ind_normal = ind[ind.obs["cell_type"] == normal_cell_type, :].copy()
print(ind_normal)

ind_tumor = ind[ind.obs["cell_type"] == tumor_cell_type, :].copy()
print(ind_tumor)
# Out:
# AnnData object with n_obs × n_vars = 600 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'
# AnnData object with n_obs × n_vars = 600 × 32286
#     obs: 'cell_type', 'cell'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'
# AnnData object with n_obs × n_vars = 600 × 32286
#     obs: 'cell_type', 'cell'
#     var: 'chrom', 'start', 'end', 'feature', 'strand'
#     layers: 'A', 'B', 'U'
# AnnData object with n_obs × n_vars = 600 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'region', 'cn0', 'cn1', 'cna_type', 'feature'
# AnnData object with n_obs × n_vars = 600 × 32286
#     obs: 'cell', 'cell_type'
#     var: 'gene_id', 'gene', 'chrom', 'start', 'end', 'strand', 'region', 'cn0', 'cn1', 'cna_type', 'feature'

# %% [markdown]
# # Save Data

# %% [markdown]
# ### Check the order of cells and genes

# %%
assert np.all(cs_normal.var["feature"].to_numpy() == seed_normal.var["feature"].to_numpy())
assert np.all(cs_tumor.var["feature"].to_numpy() == seed_normal.var["feature"].to_numpy())
assert np.all(ind_normal.var["feature"].to_numpy() == seed_normal.var["feature"].to_numpy())
assert np.all(ind_tumor.var["feature"].to_numpy() == seed_normal.var["feature"].to_numpy())

# %%
seed_normal.var.index.name = None
cs_normal.var.index.name = None
cs_tumor.var.index.name = None
ind_normal.var.index.name = None
ind_tumor.var.index.name = None

# %%
seed_normal.write_h5ad(os.path.join(out_dir, "seed_normal.h5ad"), compression = 'gzip')
cs_normal.write_h5ad(os.path.join(out_dir, "cs_normal.h5ad"), compression = 'gzip')
cs_tumor.write_h5ad(os.path.join(out_dir, "cs_tumor.h5ad"), compression = 'gzip')
ind_normal.write_h5ad(os.path.join(out_dir, "ind_normal.h5ad"), compression = 'gzip')
ind_tumor.write_h5ad(os.path.join(out_dir, "ind_tumor.h5ad"), compression = 'gzip')
